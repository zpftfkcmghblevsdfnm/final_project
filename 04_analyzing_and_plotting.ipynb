# %% [markdown]
# ## Часть 4.
# ---
# В данной части я провожу небольшой анализ полученных данных, а также строю карту для понимания местоположения каждой квартиры.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from rich.console import Console

# %%
data = pd.read_csv("data_cleaned.csv")

# %%
data.head()
# Out:
#                           name   latitude   longitude  price_sqm  \
# 0                  101 Mansion  13.787435  100.631564     243655
# 1       624 Condolette Ladprao  13.766348  100.649395      45845
# 2          Adamas Ramkhamhaeng  13.752448  100.615507      31129
# 3           Aspire Ladprao 113  13.770286  100.638799      77711
# 4  Assagarn Place Ramkhamhaeng  13.765193  100.653498      36571
#
#   change_last_q change_last_y  rental_yield change_last_y_rental_price  \
# 0             0        -13.72          0.00                          –
# 1         -3.45         -8.65          6.78                      24.52
# 2             0             0          0.00                          –
# 3         -4.28         -4.87          5.82                      -5.51
# 4             0          8.73          5.74                      -0.57
#
#                                           price_hist    district_cor  ...  \
# 0  [{"date":"2008-10-01","value":15735},{"date":"...  Khet Bang Kapi  ...
# 1  [{"date":"2010-07-01","value":36242},{"date":"...  Khet Bang Kapi  ...
# 2  [{"date":"2014-10-01","value":25258},{"date":"...  Khet Bang Kapi  ...
# 3  [{"date":"2016-10-01","value":79976},{"date":"...  Khet Bang Kapi  ...
# 4  [{"date":"2010-01-01","value":21443},{"date":"...  Khet Bang Kapi  ...
#
#    trans_dist_2  trans_type_3                 trans_name_3  trans_dist_3  \
# 0          4800    expressway      Pracha Uthit Toll Plaza          5000
# 1          6200    expressway      Pracha Uthit Toll Plaza          6500
# 2          2500    expressway    Phatthanakan 2 Toll Plaza          2900
# 3          5400    expressway     Srinagarindra Toll Plaza          6100
# 4          4000    expressway  Yothin Phatthana Toll Plaza         10000
#
#   trans_type_4  trans_name_4 trans_dist_4 trans_type_5  \
# 0          mrt     Sutthisan         8100          mrt
# 1          mrt   Huai Khwang         9800          mrt
# 2          bts  Phra Khanong         6100          bts
# 3          mrt     Sutthisan         8500          mrt
# 4          mrt   Huai Khwang        14000          mrt
#
#                trans_name_5  trans_dist_5
# 0               Huai Khwang          8300
# 1  Thailand Cultural Centre          9900
# 2                   Ekkamai          6300
# 3               Huai Khwang          8700
# 4                 Sutthisan         14000
#
# [5 rows x 72 columns]

# %%
Bangkok = ((13.45 - 0.5, 13.45 + 0.5), (100.50 - 0.2, 100.50 + 0.2))

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.set_xlim(Bangkok[1])
ax.set_ylim(Bangkok[0])
base = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
base.plot(ax=ax, color="white", edgecolor="black")
condas = data[["latitude", "longitude"]]
plt.scatter(data=condas, x="longitude", y="latitude")

# %% [markdown]
# Что ж, не так уж информативно. Попробуем сделать то же самое, но использовав библиотеку folium

# %%
map = folium.Map(location=[13.75, 100.50], zoom_start=8)
for i in range(0,len(data)):
    folium.Marker(
        location=[data.iloc[[i]]["latitude"], data.iloc[[i]]['longitude']],popup=data.iloc[[i]]["name"].to_string(), icon=folium.Icon("green")
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec9bc5dda3af01d653df1907b89adb87 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec9bc5dda3af01d653df1907b89adb87&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ec9bc5dda3af01d653df1907b89adb87 = L.map(
#                 &quot;map_ec9bc5dda3af01d653df1907b89adb87&quot;,
#                 {
#                     center: [13.75, 100.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9f79906b0bc6d7039ccd0529386ef54 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ec9bc5dda3af01d653df1907b89adb87);
#
#
#             var marker_830808b0e19df2f580305ca87360d4ac = L.marker(
#                 [13.7874348, 100.6315637],
#                 {}
#             ).addTo(map_ec9bc5dda3af01d653df1907b89adb87);
#
#
#             var icon_c087f35b740e794080210883f1885427 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_830808b0e19df2f580305ca87360d4ac.setIcon(icon_c087f35b740e794080210883f1885427);
#
#
#         var popup_8881729023e71f48d59e9d0e62ad3ce4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a8c1dfca3be5b0b4183b2c7083698a1d = $(`&lt;div id=&quot;html_a8c1dfca3be5b0b4183b2c7083698a1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0    101 Mansion&lt;/div&gt;`)[0];
#             popup_8881729023e71f48d59e9d0e62ad3ce4.setContent(html_a8c1dfca3be5b0b4183b2c7083698a1d);
#
#
#         marker_830808b0e19df2f580305ca87360d4ac.bindPopup(popup_8881729023e71f48d59e9d0e62ad3ce4)
#         ;
#
#
#
#
#             var marker_8b57715a8286295f81200c682ccfb0cb = L.marker(
#                 [13.766348, 100.649395],
#                 {}
#             ).addTo(map_ec9bc5dda3af01d653df1907b89adb87);
#
#
#             var icon_dd003015e95d5ddb61fd9d7d54cd755c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8b57715a8286295f81200c682ccfb0cb.setIcon(icon_dd003015e95d5ddb61fd9d7d54cd755c);
#
#
#         var popup_76c3e63f78a1145427a80de4549a587e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_50118ccc228323476959937f8c44c6e2 = $(`&lt;div id=&quot;html_50118ccc228323476959937f8c44c6e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1    624 Condolette Ladprao&lt;/div&gt;`)[0];
#             popup_76c3e63f78a1145427a80de4549a587e.setContent(html_50118ccc228323476959937f8c44c6e2);
#
#
#         marker_8b57715a8286295f81200c682ccfb0cb.bindPopup(popup_76c3e63f78a1145427a80de4549a587e)
#         ;
#
#
#
#
#             var marker_8f8432db455ad3a05480bbe60cb9e9ea = L.marker(
#                 [13.7524478, 100.6155072],
#                 {}
#             ).addTo(map_ec9bc5dda3af01d653df1907b89adb87);
#
#
#             var icon_62213b7fe63b7d2f4c15b82c5479e7cc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8f8432db455ad3a05480bbe60cb9e9ea.setIcon(icon_62213b7fe63b7d2f4c15b82c5479e7cc);
#
#
#         var popup_5122fb890b4b0fb3b3ce2ef3506232a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_73b2056c6e02bc7e954cacbb5709af73 = $(`&lt;div id=&quot;html_73b2056c6e02bc7e954cacbb5709af73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2    Adamas Ramkhamhaeng&lt;/div&gt;`)[0];
#             popup_5122fb890b4b0fb3b3ce2ef3506232a4.setContent(html_73b2056c6e02bc7e954cacbb5709af73);
#
#
#         marker_8f8432db455ad3a05480bbe60cb9e9ea.bindPopup(popup_5122fb890b4b0fb3b3ce2ef3506232a4)
#         ;
#
#
#
#
#             var marker_dd38695fb0b72b2795d38aa48fef70db = L.marker(
#                 [13.770286, 100.638799],
#                 {}
#             ).addTo(map_ec9bc5dda3af01d653df1907b89adb87);
#
#
#             var icon_797e1fdc9e72fff119301632f280ec74 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dd38695fb0b72b2795d38aa48fef70db

# %% [markdown]
# Довольно много. Отобразим каждую сотую запись

# %%
map = folium.Map(location=[13.75, 100.50], zoom_start=8)
for i in range(0,len(data), 100):
    folium.Marker(
        location=[data.iloc[[i]]["latitude"], data.iloc[[i]]['longitude']],popup=data.iloc[[i]]["name"].to_string(), icon=folium.Icon("green")
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_45b5fa098be00f2621aa58a7ed6f2b50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_45b5fa098be00f2621aa58a7ed6f2b50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_45b5fa098be00f2621aa58a7ed6f2b50 = L.map(
#                 &quot;map_45b5fa098be00f2621aa58a7ed6f2b50&quot;,
#                 {
#                     center: [13.75, 100.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_571ec653b50db61f773f1eaaac9913fe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_45b5fa098be00f2621aa58a7ed6f2b50);
#
#
#             var marker_03efd25ff86e0113fe1f42e323464d29 = L.marker(
#                 [13.7874348, 100.6315637],
#                 {}
#             ).addTo(map_45b5fa098be00f2621aa58a7ed6f2b50);
#
#
#             var icon_931526feb7632f7cddaae7838913ea98 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_03efd25ff86e0113fe1f42e323464d29.setIcon(icon_931526feb7632f7cddaae7838913ea98);
#
#
#         var popup_1ba560e9faf6c3524e83aee85bf9476a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ba277f6afde85f31d0f250aa55c7d073 = $(`&lt;div id=&quot;html_ba277f6afde85f31d0f250aa55c7d073&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0    101 Mansion&lt;/div&gt;`)[0];
#             popup_1ba560e9faf6c3524e83aee85bf9476a.setContent(html_ba277f6afde85f31d0f250aa55c7d073);
#
#
#         marker_03efd25ff86e0113fe1f42e323464d29.bindPopup(popup_1ba560e9faf6c3524e83aee85bf9476a)
#         ;
#
#
#
#
#             var marker_09b653dc7cedbfe0d497593fa283c5e4 = L.marker(
#                 [13.7005889, 100.5156812],
#                 {}
#             ).addTo(map_45b5fa098be00f2621aa58a7ed6f2b50);
#
#
#             var icon_17e6b5edd89f00b909ae4704b3d1e381 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_09b653dc7cedbfe0d497593fa283c5e4.setIcon(icon_17e6b5edd89f00b909ae4704b3d1e381);
#
#
#         var popup_b56727cf7bccf8b18f005a25f7e501f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_34e80780e9f688e5a86617139b9beaca = $(`&lt;div id=&quot;html_34e80780e9f688e5a86617139b9beaca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;100    Than Living Sathorn - Charoenrat&lt;/div&gt;`)[0];
#             popup_b56727cf7bccf8b18f005a25f7e501f7.setContent(html_34e80780e9f688e5a86617139b9beaca);
#
#
#         marker_09b653dc7cedbfe0d497593fa283c5e4.bindPopup(popup_b56727cf7bccf8b18f005a25f7e501f7)
#         ;
#
#
#
#
#             var marker_8029bb5c05aecb37dd4bd567c360b711 = L.marker(
#                 [13.719562, 100.519452],
#                 {}
#             ).addTo(map_45b5fa098be00f2621aa58a7ed6f2b50);
#
#
#             var icon_be4deb83e2b337f1ab5843640b8fe3d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8029bb5c05aecb37dd4bd567c360b711.setIcon(icon_be4deb83e2b337f1ab5843640b8fe3d0);
#
#
#         var popup_40d04019ac46ae938835f9bf5837fcec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f1c8c659bf158e303aafbe3a5eede10d = $(`&lt;div id=&quot;html_f1c8c659bf158e303aafbe3a5eede10d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;200    Noble Revo Silom&lt;/div&gt;`)[0];
#             popup_40d04019ac46ae938835f9bf5837fcec.setContent(html_f1c8c659bf158e303aafbe3a5eede10d);
#
#
#         marker_8029bb5c05aecb37dd4bd567c360b711.bindPopup(popup_40d04019ac46ae938835f9bf5837fcec)
#         ;
#
#
#
#
#             var marker_13425ea2fb2cb54e79966381609053c5 = L.marker(
#                 [13.802865, 100.570152],
#                 {}
#             ).addTo(map_45b5fa098be00f2621aa58a7ed6f2b50);
#
#
#             var icon_db29bdb910ee2330b597f09219d73623 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_13425ea2fb2cb54e79966

# %% [markdown]
# Исходя из этих географических данных можно сделать вывод, что большенство предлагаемых апартаментов расположены в центре города

# %% [markdown]
# ---

# %% [markdown]
# Посчитаем, во сколько нам обойдется проживание в городе Бангкоке

# %%
console = Console()
mean = data["price_sqm"].mean()
console.print(f"Средняя стоимость за метр квадратный\n{mean}")
sns.scatterplot(data=data, x=data.axes[0],y="price_sqm")
# Out:
# Средняя стоимость за метр квадратный
# 104765.75032258064
# <AxesSubplot:ylabel='price_sqm'>

# %% [markdown]
# Из данного графика видно, что в метр квадратный в Бангкоке обходится в ценовом диапазоне от 50.000 до 120.000

# %% [markdown]
# и посмотрим, что же коррелирует с данными о цене, приблизительно поняв, из чего складывается такая цена
